# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("connectsphere_churn_data.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female  SeniorCitizen     Yes         No       1           No
# 1  5575-GNVDE    Male  SeniorCitizen      No         No      34          Yes
# 2  3668-QPYBK    Male  SeniorCitizen      No         No       2          Yes
# 3  7795-CFOCW    Male  SeniorCitizen      No         No      45           No
# 4  9237-HQITU  Female  SeniorCitizen      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies ContractLength PaperlessBilling              PaymentMethod  \
# 0              No             12              Yes           Electronic check
# 1              No              3               No               Mailed check
# 2              No              4              Yes               Mailed check
# 3              No              2               No  Bank transfer (automatic)
# 4              No             12              Yes           Electronic check
#
#    MonthlyCharges TotalCharges Churn  DataUsage  CallDuration
# 0           29.85        29.85    No         40            43
# 1           56.95      1889.50    No         67            32
# 2           53.85       108.15   Yes         43            43
# 3           42.30      1840.75    No         67            12
# 4           70.70       151.65   Yes        121            34
#
# [5 rows x 23 columns]

# %%
df.dropna(inplace=True)
df['Churn'] = df['Churn'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
X = df[['CallDuration', 'DataUsage', 'ContractLength']]
y = df['Churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
log_model = LogisticRegression()
log_model.fit(X_train_scaled, y_train)

rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
log_preds = log_model.predict(X_test_scaled)
rf_preds = rf_model.predict(X_test)

print("Logistic Regression F1 Score:", f1_score(y_test, log_preds))
print("Random Forest F1 Score:", f1_score(y_test, rf_preds))
# Out:
# Logistic Regression F1 Score: 0.5
# Random Forest F1 Score: 0.4

# %%
rf_probs = rf_model.predict_proba(X)[:, 1]
df['ChurnProbability'] = rf_probs

at_risk_customers = df[df['ChurnProbability'] > 0.6]
at_risk_customers.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2   3668-QPYBK    Male  SeniorCitizen      No         No       2          Yes
# 4   9237-HQITU  Female  SeniorCitizen      No         No       2          Yes
# 5   9305-CDSKC  Female  SeniorCitizen      No         No       8          Yes
# 13  0280-XJGEX    Male  SeniorCitizen      No         No      49          Yes
# 18  4190-MFLUW  Female  SeniorCitizen     Yes        Yes      10          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... StreamingMovies  \
# 2             No             DSL            Yes  ...              No
# 4             No     Fiber optic             No  ...              No
# 5            Yes     Fiber optic             No  ...             Yes
# 13           Yes     Fiber optic             No  ...             Yes
# 18            No             DSL             No  ...              No
#
#    ContractLength PaperlessBilling              PaymentMethod MonthlyCharges  \
# 2               4              Yes               Mailed check          53.85
# 4              12              Yes           Electronic check          70.70
# 5               5              Yes           Electronic check          99.65
# 13              6              Yes  Bank transfer (automatic)         103.70
# 18             12               No    Credit card (automatic)          55.20
#
#     TotalCharges Churn DataUsage  CallDuration  ChurnProbability
# 2         108.15     1        43            43              0.66
# 4         151.65     1       121            34              0.84
# 5         820.50     1        46            55              0.67
# 13       5036.30     1       367            32              0.74
# 18        528.35     1       231            32              0.86
#
# [5 rows x 24 columns]
